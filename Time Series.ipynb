# %% [markdown]
# ## Time Series Models

# %%
from statsmodels.tsa.arima.model import ARIMA
import pandas as pd

# %%
data = pd.read_csv("VIX_data.csv",index_col="Date")
data
# Out:
#             Unemployment Rate      CPI  Three Month T Bill Rate  \
# Date
# 2014-10-01                5.7  237.430                     0.02
# 2014-11-01                5.8  236.983                     0.02
# 2014-12-01                5.6  236.252                     0.03
# 2015-01-01                5.7  234.747                     0.03
# 2015-04-01                5.4  236.222                     0.02
# ...                       ...      ...                      ...
# 2024-04-01                3.9  313.207                     5.24
# 2024-05-01                4.0  313.225                     5.25
# 2024-06-01                4.1  313.049                     5.24
# 2024-07-01                4.3  313.534                     5.20
# 2024-08-01                4.2  314.121                     5.05
#
#             Six Month T Bill Rate  10-Year Treasury Constant Maturity Rate  \
# Date
# 2014-10-01                   0.05                                     2.30
# ...

# %%
series = data["VIX_x"]
series
# Out:
# Date
# 2014-10-01    16.530
# 2014-11-01    13.330
# 2014-12-01    15.155
# 2015-01-01    19.455
# 2015-04-01    13.300
#                ...
# 2024-04-01    15.745
# 2024-05-01    12.920
# 2024-06-01    12.645
# 2024-07-01    13.190
# 2024-08-01    16.690
# Name: VIX_x, Length: 103, dtype: float64
